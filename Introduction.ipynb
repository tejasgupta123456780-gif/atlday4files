# %%
str="Hello Python Programming"
print(str[0::2])
print(str[::-1])
print(str[-6:])
print(str[-1])
# Out:
# HloPto rgamn
# gnimmargorP nohtyP olleH
# amming
# g

# %%
l=[1,2,3,'ab','bc',9.88]
print(l)
print(l[0:4])
print(l[2:7])
print(l[-1])
print(l[::-1])
l[0]=10
print(l)
# Out:
# [1, 2, 3, 'ab', 'bc', 9.88]
# [1, 2, 3, 'ab']
# [3, 'ab', 'bc', 9.88]
# 9.88
# [9.88, 'bc', 'ab', 3, 2, 1]
# [10, 2, 3, 'ab', 'bc', 9.88]

# %%
l=(1,2,3,'ab','bc',9.88)
print(l)
print(l[0:4])
print(l[2:7])
print(l[-1])
print(l[::-1])
#l[0]=10
print(l)
# Out:
# (1, 2, 3, 'ab', 'bc', 9.88)
# (1, 2, 3, 'ab')
# (3, 'ab', 'bc', 9.88)
# 9.88
# (9.88, 'bc', 'ab', 3, 2, 1)
# (1, 2, 3, 'ab', 'bc', 9.88)

# %%
d={'item':['a','b','c'],'price':[100,200,300]}
print(d)
print(d['item'])
# Out:
# {'item': ['a', 'b', 'c'], 'price': [100, 200, 300]}
# ['a', 'b', 'c']
